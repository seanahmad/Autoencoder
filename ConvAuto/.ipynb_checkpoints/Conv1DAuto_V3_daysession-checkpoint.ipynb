# %%
import os
import glob
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %matplotlib inline
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
import tensorflow as tf
tf.random.set_seed(42)

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import LocallyConnected1D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import UpSampling1D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import BatchNormalization

from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.models import clone_model

from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

from keras.utils import plot_model

# %%
timesteps = 300 #1440
input_dim = 1
n_epochs = 100
batch_size = 32
drop_rate = 0.8
n_samples = 6000

# %%
# load real-world time series trading data
def load_data(symbol):
    
    ROOT = os.path.join(r'C:\Users\vhuang\Desktop\Hazelnut', 'datasets')
    allfiles = glob.glob(os.path.join(ROOT, symbol, '*.csv'))
    n_samples = np.size(allfiles)
    
    data = np.zeros((n_samples, timesteps, input_dim))
    for i, file in enumerate(allfiles):
        df = pd.read_csv(file, usecols=[4])
        data[i] = df.values[510:810] # only use the day sessioin data
    
    return data

# %%
symbol_list = ['kiwi']
# symbol_list = ['apple', 'banana', 'cherry', 'grape', 'kiwi', 'orange']
data_dict = {}

for symbol in symbol_list:
    data_dict[symbol] = load_data(symbol)

# %%
def train_test_split(data):
    # training set is 0.8 of the total
    test_split = int(data.shape[0]*0.8)
    X_train_full = data[:test_split]
    X_test = data[test_split:]
    # validation set is 0.1 of the training
    valid_split = int(test_split*0.9)
    X_train = X_train_full[:valid_split]
    X_valid = X_train_full[valid_split:]
    
    return X_train, X_test, X_valid

# %%
RawData = data_dict['kiwi'].copy()

X_train, X_test, X_valid = train_test_split(RawData)

# %%
def preprocess(data):
    for i in range(data.shape[0]):
        scaler = StandardScaler()
        data[i] = scaler.fit_transform(data[i])
        
    return data

# %%
X_train = preprocess(X_train)
X_test = preprocess(X_test)
X_valid = preprocess(X_valid)

# %%
print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)
# Out:
# (3866, 300, 1)
# (1075, 300, 1)
# (430, 300, 1)

# %%
plt.plot(X_train[100])

# %%
plt.plot(X_train[3000])

# %%
plt.plot(X_train[573])

# %%
# Convolutional Autoencoder
# with more Conv1D layers

# %% [markdown]
# $$new\ width(height) = \frac{width(height) - F + 2 \times P}{S} + 1$$

# %%
# input sequence
input_seq = Input(shape=(timesteps, input_dim))

# encoder with Conv1D and MaxPooling1D
X = Conv1D(filters=4, kernel_size=3, strides=1, padding='causal', activation='relu')(input_seq)
X = BatchNormalization()(X)
X = MaxPooling1D(4, padding='valid')(X)

X = Conv1D(filters=8, kernel_size=3, strides=1, padding='causal', activation='relu')(X)
X = BatchNormalization()(X)
X = Conv1D(filters=8, kernel_size=3, strides=1, padding='causal', activation='relu')(X)
X = BatchNormalization()(X)
X = MaxPooling1D(5, padding='valid')(X)

X = Conv1D(filters=10, kernel_size=3, strides=1, padding='causal', activation='relu')(X)
X = BatchNormalization()(X)
X = Conv1D(filters=10, kernel_size=3, strides=1, padding='causal', activation='relu')(X)
X = BatchNormalization()(X)
encoded = MaxPooling1D(5, padding='valid')(X)

# %%
# decoder with Conv1D and UpSampling1D
X = Conv1D(filters=10, kernel_size=3, strides=1, padding='causal', activation='relu')(encoded)
X = BatchNormalization()(X)
X = Conv1D(filters=10, kernel_size=3, strides=1, padding='causal', activation='relu')(X)
X = BatchNormalization()(X)
X = UpSampling1D(5)(X)

X = Conv1D(filters=8, kernel_size=3, strides=1, padding='causal', activation='relu')(X)
X = BatchNormalization()(X)
X = Conv1D(filters=8, kernel_size=3, strides=1, padding='causal', activation='relu')(X)
X = BatchNormalization()(X)
X = UpSampling1D(5)(X)

X = Conv1D(filters=4, kernel_size=3, strides=1, padding='causal', activation='relu')(X)
X = BatchNormalization()(X)
X = UpSampling1D(4)(X)
decoded = Conv1D(filters=1, kernel_size=3, strides=1, padding='causal', activation='sigmoid')(X)

# %%
Conv1DAuto_Real = Model(inputs=[input_seq], outputs=[decoded])

# %%
Conv1DAuto_Real.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 300, 1)]          0
# _________________________________________________________________
# conv1d_99 (Conv1D)           (None, 300, 4)            16
# _________________________________________________________________
# batch_normalization_v2_90 (B (None, 300, 4)            16
# _________________________________________________________________
# max_pooling1d_27 (MaxPooling (None, 75, 4)             0
# _________________________________________________________________
# conv1d_100 (Conv1D)          (None, 75, 8)             104
# _________________________________________________________________
# batch_normalization_v2_91 (B (None, 75, 8)             32
# _________________________________________________________________
# conv1d_101 (Conv1D)          (None, 75, 8)             200
# _________________________________________________________________
# batch_normalization_v2_92 (B (None, 75, 8)             32
# _________________________________________________________________
# max_pooling1d_28 (MaxPooling (None, 15, 8)             0
# _________________________________________________________________
# conv1d_102 (Conv1D)          (None, 15, 10)            250
# _________________________________________________________________
# batch_normalization_v2_93 (B (None, 15, 10)            40
# _________________________________________________________________
# conv1d_103 (Conv1D)          (None, 15, 10)            310
# _________________________________________________________________
# batch_normalization_v2_94 (B (None, 15, 10)            40
# _________________________________________________________________
# max_pooling1d_29 (MaxPooling (None, 3, 10)             0
# _________________________________________________________________
# conv1d_104 (Conv1D)          (None, 3, 10)             310
# _________________________________________________________________
# batch_normalization_v2_95 (B (None, 3, 10)             40
# _________________________________________________________________
# conv1d_105 (Conv1D)          (None, 3, 10)             310
# _________________________________________________________________
# batch_normalization_v2_96 (B (None, 3, 10)             40
# _________________________________________________________________
# up_sampling1d_27 (UpSampling (None, 15, 10)            0
# _________________________________________________________________
# conv1d_106 (Conv1D)          (None, 15, 8)             248
# _________________________________________________________________
# batch_normalization_v2_97 (B (None, 15, 8)             32
# _________________________________________________________________
# conv1d_107 (Conv1D)          (None, 15, 8)             200
# _________________________________________________________________
# batch_normalization_v2_98 (B (None, 15, 8)             32
# _________________________________________________________________
# up_sampling1d_28 (UpSampling (None, 75, 8)             0
# _________________________________________________________________
# conv1d_108 (Conv1D)          (None, 75, 4)             100
# _________________________________________________________________
# batch_normalization_v2_99 (B (None, 75, 4)             16
# _________________________________________________________________
# up_sampling1d_29 (UpSampling (None, 300, 4)            0
# _________________________________________________________________
# conv1d_109 (Conv1D)          (None, 300, 1)            13
# =================================================================
# Total params: 2,381
# Trainable params: 2,221
# Non-trainable params: 160
# _________________________________________________________________

# %%
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999,
                                  epsilon=None, decay=0.0, amsgrad=False)

checkpoint_cb = ModelCheckpoint('Conv1DAuto_Real_daySession.h5', save_best_only=True)

earlystopping_cb = EarlyStopping(patience=5)

# %%
Conv1DAuto_Real.compile(loss='mse', optimizer=optimizer,
                     metrics=['mse'])

# %%
history_real = Conv1DAuto_Real.fit(X_train, X_train, batch_size=batch_size, epochs=n_epochs,
                        callbacks=[checkpoint_cb, earlystopping_cb], 
                        validation_data=(X_valid, X_valid))
# Out:
# Train on 3866 samples, validate on 430 samples
# Epoch 1/100
# 3866/3866 [==============================] - 6s 2ms/sample - loss: 1.0622 - mse: 1.0622 - val_loss: 0.8953 - val_mse: 0.8953
# Epoch 2/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.8227 - mse: 0.8227 - val_loss: 0.6841 - val_mse: 0.6841
# Epoch 3/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.7549 - mse: 0.7549 - val_loss: 0.6398 - val_mse: 0.6398 loss: 0.7599
# Epoch 4/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.7201 - mse: 0.7201 - val_loss: 0.6163 - val_mse: 0.6163
# Epoch 5/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6989 - mse: 0.6989 - val_loss: 0.6000 - val_mse: 0.6000
# Epoch 6/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6883 - mse: 0.6883 - val_loss: 0.5951 - val_mse: 0.5951
# Epoch 7/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6820 - mse: 0.6820 - val_loss: 0.5922 - val_mse: 0.5922
# Epoch 8/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6774 - mse: 0.6774 - val_loss: 0.5866 - val_mse: 0.5866
# Epoch 9/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6735 - mse: 0.6735 - val_loss: 0.5858 - val_mse: 0.5858
# Epoch 10/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6707 - mse: 0.6707 - val_loss: 0.5822 - val_mse: 0.5822
# Epoch 11/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6681 - mse: 0.6681 - val_loss: 0.5811 - val_mse: 0.5811
# Epoch 12/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6660 - mse: 0.6660 - val_loss: 0.5797 - val_mse: 0.5797
# Epoch 13/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6635 - mse: 0.6635 - val_loss: 0.5784 - val_mse: 0.5784
# Epoch 14/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6619 - mse: 0.6619 - val_loss: 0.5779 - val_mse: 0.5779
# Epoch 15/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6610 - mse: 0.6610 - val_loss: 0.5748 - val_mse: 0.5748
# Epoch 16/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6600 - mse: 0.6600 - val_loss: 0.5727 - val_mse: 0.5727
# Epoch 17/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6583 - mse: 0.6583 - val_loss: 0.5726 - val_mse: 0.5726
# Epoch 18/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6568 - mse: 0.6568 - val_loss: 0.5711 - val_mse: 0.5711
# Epoch 19/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6556 - mse: 0.6556 - val_loss: 0.5702 - val_mse: 0.5702
# Epoch 20/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6553 - mse: 0.6553 - val_loss: 0.5689 - val_mse: 0.5689
# Epoch 21/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6538 - mse: 0.6538 - val_loss: 0.5682 - val_mse: 0.5682
# Epoch 22/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6530 - mse: 0.6530 - val_loss: 0.5681 - val_mse: 0.5681
# Epoch 23/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6516 - mse: 0.6516 - val_loss: 0.5669 - val_mse: 0.5669
# Epoch 24/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6505 - mse: 0.6505 - val_loss: 0.5666 - val_mse: 0.5666
# Epoch 25/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6502 - mse: 0.6502 - val_loss: 0.5665 - val_mse: 0.5665
# Epoch 26/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6493 - mse: 0.6493 - val_loss: 0.5654 - val_mse: 0.5654
# Epoch 27/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6483 - mse: 0.6483 - val_loss: 0.5639 - val_mse: 0.5639
# Epoch 28/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6478 - mse: 0.6478 - val_loss: 0.5635 - val_mse: 0.5635
# Epoch 29/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6463 - mse: 0.6463 - val_loss: 0.5633 - val_mse: 0.5633
# Epoch 30/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6460 - mse: 0.6460 - val_loss: 0.5621 - val_mse: 0.5621
# Epoch 31/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6455 - mse: 0.6455 - val_loss: 0.5614 - val_mse: 0.5614
# Epoch 32/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6443 - mse: 0.6443 - val_loss: 0.5607 - val_mse: 0.5607
# Epoch 33/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6443 - mse: 0.6443 - val_loss: 0.5603 - val_mse: 0.5603
# Epoch 34/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6430 - mse: 0.6430 - val_loss: 0.5598 - val_mse: 0.5598
# Epoch 35/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6422 - mse: 0.6422 - val_loss: 0.5585 - val_mse: 0.5585
# Epoch 36/100
# 3866/3866 [==============================] - 4s 988us/sample - loss: 0.6413 - mse: 0.6413 - val_loss: 0.5591 - val_mse: 0.5591
# Epoch 37/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6412 - mse: 0.6412 - val_loss: 0.5573 - val_mse: 0.5573
# Epoch 38/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6413 - mse: 0.6413 - val_loss: 0.5568 - val_mse: 0.5568
# Epoch 39/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6405 - mse: 0.6405 - val_loss: 0.5561 - val_mse: 0.5561
# Epoch 40/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6396 - mse: 0.6396 - val_loss: 0.5559 - val_mse: 0.5559
# Epoch 41/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6392 - mse: 0.6392 - val_loss: 0.5556 - val_mse: 0.5556
# Epoch 42/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6387 - mse: 0.6387 - val_loss: 0.5556 - val_mse: 0.5556
# Epoch 43/100
# 3866/3866 [==============================] - 4s 991us/sample - loss: 0.6383 - mse: 0.6383 - val_loss: 0.5559 - val_mse: 0.5559
# Epoch 44/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6372 - mse: 0.6372 - val_loss: 0.5544 - val_mse: 0.5544
# Epoch 45/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6380 - mse: 0.6380 - val_loss: 0.5535 - val_mse: 0.5535
# Epoch 46/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6369 - mse: 0.6369 - val_loss: 0.5530 - val_mse: 0.5530
# Epoch 47/100
# 3866/3866 [==============================] - 4s 991us/sample - loss: 0.6368 - mse: 0.6368 - val_loss: 0.5532 - val_mse: 0.5532ss: 0.6382 - - ETA: 1s - loss: 0
# Epoch 48/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6357 - mse: 0.6357 - val_loss: 0.5520 - val_mse: 0.5520
# Epoch 49/100
# 3866/3866 [==============================] - 4s 991us/sample - loss: 0.6358 - mse: 0.6358 - val_loss: 0.5530 - val_mse: 0.5530
# Epoch 50/100
# 3866/3866 [==============================] - 4s 985us/sample - loss: 0.6351 - mse: 0.6351 - val_loss: 0.5528 - val_mse: 0.5528
# Epoch 51/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6347 - mse: 0.6347 - val_loss: 0.5518 - val_mse: 0.5518
# Epoch 52/100
# 3866/3866 [==============================] - 4s 994us/sample - loss: 0.6344 - mse: 0.6344 - val_loss: 0.5530 - val_mse: 0.5530
# Epoch 53/100
# 3866/3866 [==============================] - 4s 986us/sample - loss: 0.6341 - mse: 0.6341 - val_loss: 0.5518 - val_mse: 0.5518
# Epoch 54/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6341 - mse: 0.6341 - val_loss: 0.5517 - val_mse: 0.5517
# Epoch 55/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6333 - mse: 0.6333 - val_loss: 0.5507 - val_mse: 0.5507
# Epoch 56/100
# 3866/3866 [==============================] - 4s 993us/sample - loss: 0.6333 - mse: 0.6333 - val_loss: 0.5511 - val_mse: 0.5511
# Epoch 57/100
# 3866/3866 [==============================] - 4s 984us/sample - loss: 0.6331 - mse: 0.6331 - val_loss: 0.5514 - val_mse: 0.5514
# Epoch 58/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6326 - mse: 0.6326 - val_loss: 0.5506 - val_mse: 0.5506
# Epoch 59/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6323 - mse: 0.6323 - val_loss: 0.5506 - val_mse: 0.5506
# Epoch 60/100
# 3866/3866 [==============================] - 4s 991us/sample - loss: 0.6325 - mse: 0.6325 - val_loss: 0.5513 - val_mse: 0.5513
# Epoch 61/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6319 - mse: 0.6319 - val_loss: 0.5495 - val_mse: 0.5495
# Epoch 62/100
# 3866/3866 [==============================] - 4s 991us/sample - loss: 0.6317 - mse: 0.6317 - val_loss: 0.5500 - val_mse: 0.5500
# Epoch 63/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6313 - mse: 0.6313 - val_loss: 0.5492 - val_mse: 0.5492
# Epoch 64/100
# 3866/3866 [==============================] - 4s 986us/sample - loss: 0.6311 - mse: 0.6311 - val_loss: 0.5492 - val_mse: 0.5492
# Epoch 65/100
# 3866/3866 [==============================] - 4s 999us/sample - loss: 0.6311 - mse: 0.6311 - val_loss: 0.5506 - val_mse: 0.5506
# Epoch 66/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6305 - mse: 0.6305 - val_loss: 0.5490 - val_mse: 0.5490
# Epoch 67/100
# 3866/3866 [==============================] - 4s 979us/sample - loss: 0.6310 - mse: 0.6310 - val_loss: 0.5497 - val_mse: 0.5497
# Epoch 68/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6302 - mse: 0.6302 - val_loss: 0.5489 - val_mse: 0.5489
# Epoch 69/100
# 3866/3866 [==============================] - 4s 982us/sample - loss: 0.6301 - mse: 0.6301 - val_loss: 0.5502 - val_mse: 0.5502
# Epoch 70/100
# 3866/3866 [==============================] - 4s 981us/sample - loss: 0.6299 - mse: 0.6299 - val_loss: 0.5502 - val_mse: 0.5502
# Epoch 71/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6300 - mse: 0.6300 - val_loss: 0.5478 - val_mse: 0.5478
# Epoch 72/100
# 3866/3866 [==============================] - 4s 979us/sample - loss: 0.6297 - mse: 0.6297 - val_loss: 0.5494 - val_mse: 0.5494
# Epoch 73/100
# 3866/3866 [==============================] - 4s 994us/sample - loss: 0.6293 - mse: 0.6293 - val_loss: 0.5487 - val_mse: 0.5487
# Epoch 74/100
# 3866/3866 [==============================] - 4s 993us/sample - loss: 0.6294 - mse: 0.6294 - val_loss: 0.5487 - val_mse: 0.5487
# Epoch 75/100
# 3866/3866 [==============================] - 4s 990us/sample - loss: 0.6289 - mse: 0.6289 - val_loss: 0.5482 - val_mse: 0.5482
# Epoch 76/100
# 3866/3866 [==============================] - 4s 1ms/sample - loss: 0.6294 - mse: 0.6294 - val_loss: 0.5481 - val_mse: 0.5481

# %%
plt.plot(history_real.history['loss'])
plt.plot(history_real.history['val_loss'])

# %%
X_pred = Conv1DAuto_Real.predict(X_test)

# %%
for i in range(len(X_pred)):
    if i % 30 == 0:
        plt.figure(figsize=(6,4))
        plt.plot(X_test[i])
        plt.plot(X_pred[i])
# Out:
# C:\Users\vhuang\Anaconda3\envs\py36tf2\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
